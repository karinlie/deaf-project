# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()
# !yolo mode=checks
# Out:
# Traceback (most recent call last):
#   File "C:\Users\Karin\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\Karin\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "c:\Users\Karin\alarm-detector\backend\venv\Scripts\yolo.exe\__main__.py", line 7, in <module>
#   File "C:\Users\Karin\alarm-detector\backend\venv\lib\site-packages\ultralytics\cfg\__init__.py", line 920, in entrypoint
#     raise ValueError(f"Invalid 'mode={mode}'. Valid modes are {MODES}.\n{CLI_HELP_MSG}")
# ValueError: Invalid 'mode=<module 'ultralytics.utils.checks' from 'C:\\Users\\Karin\\alarm-detector\\backend\\venv\\lib\\site-packages\\ultralytics\\utils\\checks.py'>'. Valid modes are frozenset({'track', 'train', 'val', 'predict', 'export', 'benchmark'}).
#
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="AXUR8aJWdUJMuNxRuB0S")
project = rf.workspace("computervision-project-ozcsf").project("computer-vision-iuk5g")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Computer-vision-1 in yolov8:: 100%|██████████| 22/22 [00:00<00:00, 797.02it/s]

# %%
file_path = r'"C:\\Users\\Karin\\alarm-detector\backend\\Computer-vision-1\\data.yaml"'
# !yolo task=detect mode=train model=yolov8n.pt data={filepath} epochs=20 imgsz=640
# Out:
# ...
# Ultralytics 8.3.93 🚀 Python-3.10.4 torch-2.6.0+cpu CPU (AMD Ryzen 7 5800U with Radeon Graphics)
# ...

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')

results = model(source=0, show=True, conf=0.3, save=True)
# Out:
# WARNING  Environment does not support cv2.imshow() or PIL Image.show()
# OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:1301: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvShowImage'
#
#
# 1/1: 0... Success  (inf frames of shape 640x480 at 30.00 FPS)
#
#
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
# ...

# %%
from ultralytics import YOLO
import cv2

# Last inn modellen
model = YOLO('yolov8n.pt')

# Kjør YOLO på webkamera (source=0)
results = model(source=0, conf=0.3)

# Gå gjennom resultatene og vis bildene manuelt
for result in results:
    frame = result.plot()  # Få bildet med tegnet bounding box
    cv2.imshow('YOLO Detection', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):  # Trykk 'q' for å avslutte
        break

cv2.destroyAllWindows()
# Out:
# 1/1: 0... Success  (inf frames of shape 640x480 at 30.00 FPS)
#
#
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# 0: 480x640 1 person, 70.5ms
# 0: 480x640 1 person, 60.9ms
# 0: 480x640 1 person, 50.4ms
# 0: 480x640 1 person, 57.6ms
# 0: 480x640 1 person, 54.4ms
# 0: 480x640 1 person, 52.8ms
# 0: 480x640 1 person, 53.6ms
# 0: 480x640 1 person, 54.5ms
# 0: 480x640 1 person, 59.8ms
# 0: 480x640 1 person, 55.3ms
# 0: 480x640 1 person, 57.3ms
# 0: 480x640 1 person, 55.4ms
# ...

# %%
import matplotlib.pyplot as plt

for result in results:
    frame = result.plot()
    plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
    plt.axis('off')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 3>()
#       1 import matplotlib.pyplot as plt
# ----> 3 for result in results:
#       4     frame = result.plot()
#       5     plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
#
# NameError: name 'results' is not defined
